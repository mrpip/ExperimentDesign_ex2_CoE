# %%
import sys
import os
os.chdir(r'C:\Users\Pia\OneDrive\Data Science\experiment_design\ex_2\CoE_dataset')

import numpy as np
import pandas as pd
pd.options.display.max_columns = 34
pd.options.display.max_rows = 100

from datetime import datetime
import xml.etree.ElementTree as et
from random import seed, sample, choice
import sklearn as sk
from sklearn.model_selection import cross_validate
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# modules imported successfully

# %% [markdown]
# ## Use this chunk of code for loading the training data
# We'll do one-hot encoding after feature selection

# %%
# afterwards we'll do the same thing for the test set
data_set = 'Dev'

# get the columnnames:
xtree = et.parse(r'Dev_Set\XML\A_Fish_Called_Wanda.xml')
xroot = xtree.getroot()
columns = list(xroot.find('movie').keys())
df = pd.DataFrame(columns = columns)

for movie_name in os.listdir(data_set + '_Set/XML'):  
    xtree = et.parse(data_set + '_Set/XML/' + movie_name)
    xroot = xtree.getroot()
    instance = []
    for element in columns:
        if xroot[0] is not None: # and element != 'goodforairplane': # feature "good for airplane" is not filled in 
            instance.append(xroot.find('movie').get(element))
        else:
            pass
    if len(instance) < len(columns):
        instance.append(movie_name[:-3])
    my_series = pd.Series(instance, index = columns)
    df = df.append(my_series, ignore_index=True)

df.set_index('title', inplace=True)

df = df.loc[:, ['language', 'year', 'genre', 'country', 'runtime', 'rated']]

# make the feature 'runtime' numeric:
df.runtime = df.runtime.apply(lambda x: x[:-4])
df.runtime = pd.to_numeric(df.runtime, errors='coerce')

# bring the entries of 'rated' which were not filled out into a unique shape:
df.rated.replace(['NOT RATED', 'UNRATED'], 'N/A', inplace=True)

df.year = pd.to_numeric(df.year, errors='coerce')

labels = pd.read_excel(r'Dev_Set\dev_set_groundtruth_and_trailers.xls', index_col=0).goodforairplane
df.head(100)
# Out:
#                                                                       language  \
# title
# American Gangster                                                      English
# American Pie                                                           English
# Andaz Apna Apna                                                          Hindi
# Anna Karenina                                                          English
# A Fish Called Wanda                                  English, Italian, Russian
# A Goofy Movie                                                          English
# A Million Ways to Die in the West                    English, Navajo, Mandarin
# A Single Man                                                  English, Spanish
# Babar: The Movie                                               English, French
# Bhoothnath Returns                                                       Hindi
# Big Hero 6                                                             English
# Black Swan                                            English, French, Italian
# Bobby Jasoos                                                       Urdu, Hindi
# Boogie Nights                                                          English
# Bronson                                                                English
# Bros Before Hos                                                          Dutch
# Brother Bear                             English, Inuktitut, Croatian, Serbian
# Casino Royale                                                  English, French
# Chef                                                          English, Spanish
# Dirty Dancing                                                          English
# Donnie Darko                                                           English
# Drive                                                         English, Spanish
# Elsa & Fred                                          Spanish, Italian, English
# Excuse My French                                                        Arabic
# Exodus: Gods and Kings                                                 English
# Full Metal Jacket                                          English, Vietnamese
# Grand Piano                                                            English
# Homies                                                                   Dutch
# Hook                                                                   English
# Hotel Transylvania                                                     English
# Inherent Vice                                                English, Japanese
# Interstellar                                                           English
# Into the Wild                                                  English, Danish
# Into the Woods                                                         English
# Invincible                                                             English
# Jack Reacher                                                           English
# Jerry Maguire                                  English, American Sign Language
# John Wick                                          English, Russian, Hungarian
# Khoobsurat                                                               Hindi
# Khumba                                                                 English
# Full Metal Jacket                        1987                    Drama, War
# Grand Piano                              2013      Music, Mystery, Thriller
# Homies                                   2015                        Comedy
# Hook                                     1991     Adventure, Comedy, Family
# Hotel Transylvania                       2012     Animation, Comedy, Family
# Inherent Vice                            2014         Crime, Drama, Mystery
# Interstellar                             2014             Adventure, Sci-Fi
# Into the Wild                            2007   Adventure, Biography, Drama
# Into the Woods                           2014   Adventure, Fantasy, Musical
# Invincible                               2006       Biography, Drama, Sport
# Jack Reacher                             2012     Action, Mystery, Thriller
# Jerry Maguire                            1996        Comedy, Drama, Romance
# John Wick                                2014              Action, Thriller
# Khoobsurat                               2014               Comedy, Romance
# Khumba                                   2013  Animation, Adventure, Family
# Let's Be Cops                            2014                        Comedy
# Le Samourai                              1967         Crime, Drama, Mystery
# Live Nude Girls                          1995                        Comedy
# Looney Tunes: Back in Action             2003  Animation, Adventure, Comedy
# Lord of the Flies                        1990    Adventure, Drama, Thriller
# Maine Pyar Kiya                          1989      Family, Musical, Romance
# Mean Girls                               2004                        Comedy
# Monsters University                      2013  Animation, Adventure, Comedy
# Moulin Rouge!                            2001       Drama, Musical, Romance
# Mr. Go                                   2013          Comedy, Drama, Sport
# Mulan                                    1998  Animation, Adventure, Family
# My Week with Marilyn                     2011              Biography, Drama
# Nightcrawler                             2014               Crime, Thriller
# Night at the Museum: Secret of the Tomb  2014     Adventure, Comedy, Family
# Ode to My Father                         2014                         Drama
# Perez.                                   2014        Crime, Drama, Thriller
# Predestination                           2014        Drama, Mystery, Sci-Fi
# Pulp Fiction                             1994                  Crime, Drama
# RED                                      2010         Action, Comedy, Crime
# Robin Hood                               2010      Action, Adventure, Drama
# Seventh Son                              2014    Action, Adventure, Fantasy
# Shakespeare in Love                      1998        Comedy, Drama, Romance
# Some Like It Hot                         1959                        Comedy
# Still Alice                              2014                         Drama
# The Babadook                             2014       Drama, Horror, Thriller
# The Birdcage                             1996                        Comedy
# The Blair Witch Project                  1999               Horror, Mystery
# The Book of Life                         2014  Animation, Adventure, Comedy
# The Bourne Legacy                        2012    Action, Adventure, Mystery
# The Cobbler                              2014        Comedy, Drama, Fantasy
# The Dark Knight                          2008          Action, Crime, Drama
# The Fault in Our Stars                   2014                Drama, Romance
# The Great Gatsby                         2013                Drama, Romance
# The Hobbit: The Desolation of Smaug      2013            Adventure, Fantasy
# The Hunger Games                         2012             Adventure, Sci-Fi
# The Hunger Games: Catching Fire          2013             Adventure, Sci-Fi
# The Imitation Game                       2014    Biography, Drama, Thriller
# The Judge                                2014                         Drama
# The Last Days on Mars                    2013      Horror, Sci-Fi, Thriller
# The Lizzie McGuire Movie                 2003     Adventure, Comedy, Family
# The Matrix                               1999                Action, Sci-Fi
# The Maze Runner                          2014       Action, Mystery, Sci-Fi
# The Normal Heart                         2014                         Drama
# The Parent Trap                          1998      Adventure, Comedy, Drama
# The Phantom Tollbooth                    1970  Family, Adventure, Animation
# The Reader                               2008                Drama, Romance
# The Reluctant Dragon                     1941     Animation, Comedy, Family
# The Hunger Games: Catching Fire                                                USA
# The Imitation Game                                                         UK, USA
# The Judge                                                                      USA
# The Last Days on Mars                                                  UK, Ireland
# The Lizzie McGuire Movie                                                       USA
# The Matrix                                                          USA, Australia
# The Maze Runner                                                                USA
# The Normal Heart                                                               USA
# The Parent Trap                                                                USA
# The Phantom Tollbooth                                                          USA
# The Reader                                                            USA, Germany
# The Reluctant Dragon                                                           USA
# The Theory of Everything                                                        UK
# This Is Where I Leave You                                                      USA
# Total Recall                                                                   USA
# Transformers: Age of Extinction                                         USA, China
# V for Vendetta                                                    USA, UK, Germany
# Welcome to Me                                                                  USA
# Wild Tales                                                        Argentina, Spain
# Words and Pictures                                                             USA
#
#                                          runtime     rated
# title
# American Gangster                            157         R
# American Pie                                  95         R
# Andaz Apna Apna                              160        PG
# Anna Karenina                                129         R
# A Fish Called Wanda                          108         R
# A Goofy Movie                                 78         G
# A Million Ways to Die in the West            116         R
# A Single Man                                  99         R
# Babar: The Movie                              70         G
# Bhoothnath Returns                           155       N/A
# Big Hero 6                                   102        PG
# Black Swan                                   108         R
# Bobby Jasoos                                 121       N/A
# Boogie Nights                                155         R
# Bronson                                       92         R
# Bros Before Hos                               87       N/A
# Brother Bear                                  85         G
# Casino Royale                                144     PG-13
# Chef                                         114         R
# Dirty Dancing                                100     PG-13
# Donnie Darko                                 113         R
# Drive                                        100         R
# Elsa & Fred                                  108        PG
# Excuse My French                              99       N/A
# Exodus: Gods and Kings                       150     PG-13
# Full Metal Jacket                            116         R
# Grand Piano                                   90         R
# Homies                                       100       N/A
# Hook                                         142        PG
# Hotel Transylvania                            91        PG
# Inherent Vice                                148         R
# Interstellar                                 169     PG-13
# Into the Wild                                148         R
# Into the Woods                               125        PG
# Invincible                                   105        PG
# Jack Reacher                                 130     PG-13
# Jerry Maguire                                139         R
# John Wick                                    101         R
# Khoobsurat                                   130       N/A
# Khumba                                        85       N/A
# Let's Be Cops                                104         R
# Le Samourai                                  101        PG
# Live Nude Girls                               95         R
# Looney Tunes: Back in Action                  91        PG
# Lord of the Flies                             90         R
# Maine Pyar Kiya                              192       N/A
# Mean Girls                                    97     PG-13
# Monsters University                          104         G
# Moulin Rouge!                                127     PG-13
# Mr. Go                                       132       N/A
# Mulan                                         88         G
# My Week with Marilyn                          99         R
# Nightcrawler                                 117         R
# Night at the Museum: Secret of the Tomb       98        PG
# Ode to My Father                             126       N/A
# Perez.                                        94       N/A
# Predestination                                97         R
# Pulp Fiction                                 154         R
# RED                                          111     PG-13
# Robin Hood                                   140     PG-13
# Seventh Son                                  102     PG-13
# Shakespeare in Love                          123         R
# Some Like It Hot                             120       N/A
# Still Alice                                  101     PG-13
# The Babadook                                  93       N/A
# The Birdcage                                 117         R
# The Blair Witch Project                       81         R
# The Book of Life                              95        PG
# The Bourne Legacy                            135     PG-13
# The Cobbler                                   99     PG-13
# The Dark Knight                              152     PG-13
# The Fault in Our Stars                       126     PG-13
# The Great Gatsby                             143     PG-13
# The Hobbit: The Desolation of Smaug          161     PG-13
# The Hunger Games                             142     PG-13
# The Hunger Games: Catching Fire              146     PG-13
# The Imitation Game                           114     PG-13
# The Judge                                    141         R
# The Last Days on Mars                         98         R
# The Lizzie McGuire Movie                      94        PG
# The Matrix                                   136         R
# The Maze Runner                              113     PG-13
# The Normal Heart                             132     TV-MA
# The Parent Trap                              127        PG
# The Phantom Tollbooth                         90         G
# The Reader                                   124         R
# The Reluctant Dragon                          74  APPROVED
# The Theory of Everything                     123     PG-13
# This Is Where I Leave You                    103         R
# Total Recall                                 113         R
# Transformers: Age of Extinction              165     PG-13
# V for Vendetta                               132         R
# Welcome to Me                                105         R
# Wild Tales                                   122         R
# Words and Pictures                           111     PG-13

# %% [markdown]
# ## Use this for computing the metrics:

# %%
def compute_scores(X, y, classifier):
    
    if classifier == 'knn':
        clf = KNeighborsClassifier()
        
    elif classifier == 'nearest_mean':
        clf = NearestCentroid()
        
    elif classifier == 'decision_tree':
        clf = DecisionTreeClassifier()
        
    elif classifier == 'logistic_regression':
        clf = LogisticRegression(solver='lbfgs')  # for not getting warnings
        
    elif classifier == 'svm':
        clf = SVC(kernel = 'rbf', gamma='auto')  # for avoiding warnings    
            
    elif classifier == 'bagging':
        clf = BaggingClassifier()
        
    elif classifier == 'random_forest':
        clf = RandomForestClassifier(n_estimators=10)  # for not getting warnings
        
    elif classifier == 'adaboost':
        clf = AdaBoostClassifier()
        
    elif classifier == 'gradient_boost':
        clf = GradientBoostingClassifier()
        
    else:
        print('Parameter \'classifier\' needs to be one of the following strings:' )
        print('\'knn\', \'decision_tree\', \'logisticregression\', \'svm\', \'random_forest\', \'adaboost\', \'gradient_boost\'')
        return
    
    np.random.seed(1)  # scikit-learn uses numpy.random
    return cross_validate(clf, X, y, cv = 10, scoring = ['precision', 'recall', 'f1'])

# %%
# something is still not working, if you run this chunk of code a second time, the features, that are elected are less and the 
# scores are lower

def get_dummies(df, selected_features=['language', 'genre', 'country', 'rated']):
    
    df_tmp = df.copy()
    for feature in set(selected_features).intersection(['language', 'genre', 'country', 'rated']):  # we only get dummy 
                                                                                                     # variables for categorical
                                                                                                      # data
        # split the variables with various entries: 
        one_hot = df.copy().loc[:, feature].str.split(', ', expand=True).stack()
        
        one_hot = pd.get_dummies(one_hot, prefix=feature, drop_first=True).groupby(level=0).sum()
        df_tmp = df_tmp.drop(feature, axis=1)
        df_tmp = df_tmp.merge(one_hot, left_index=True, right_index=True)
    
    return df_tmp

    
def LVW(X, y, K, classifier):
     
    original_features = list(X.columns)    
    f1_best = 0
    k = 0
    C = len(original_features)
        
    seed(1)  # seed for package 'random'
    while k < K:
        sample_sizes = range(1, C + 1)
        my_choice = choice(sample_sizes)
        S1 = sample(original_features, my_choice)
        C1 = len(S1)
        
        # take a subset of the original dataframe X:
        X1 = X.copy().loc[:, S1]
        
        X1 = get_dummies(X1, S1)
        
        scores = compute_scores(X1, y, classifier)
        f1 = np.mean(scores['test_f1'])
        
        if (f1 > f1_best) or (f1 == f1_best and C1 < C):
            k, f1_best, C, S  = 0, f1, C1, S1
            precision, recall = np.mean(scores['test_precision']), np.mean(scores['test_recall'])
        else:
            k += 1
        
    # get a string: 
    used_features = S[0]
    for feature in S[1:]:
        used_features += ', ' + feature
    print(S)

    return pd.DataFrame({'classifier': [classifier], 'used_features': [used_features], 'precision': [precision], 
                         'recall': [recall], 'f1': f1_best}, index=['classifier'])


# as the decision tree does not need the LVW, we compute it first without the LVW: 
scores_tree = compute_scores(get_dummies(df), labels, 'decision_tree')

scores = pd.DataFrame({'classifier': ['decision_tree'], 'used_features': ['all'], 
                       'precision': [np.mean(scores_tree['test_precision'])], 
                       'recall': [np.mean(scores_tree['test_recall'])], 'f1': np.mean(scores_tree['test_f1'])},
                        index=['classifier'])

for clf in ['knn', 'nearest_mean', 'logistic_regression', 'svm', 'bagging', 'random_forest', 'adaboost', 'gradient_boost']: 
    scores = scores.append(LVW(df, labels, 10, clf))
scores
# Out:
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['language']
# ['language', 'country']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# ['language']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['rated']
# ['country']
# ['country']
# ['runtime']
# ['country']
# ['runtime', 'year']
# ['year', 'rated']
# ['genre', 'language']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['genre', 'year']
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language', 'country']
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# ['language']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['rated']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['country']
# ['runtime', 'language']
# ['runtime', 'language']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language', 'country']
# ['runtime', 'language']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ['genre', 'year']
# ['genre']
# ['language']
# ['rated']
# ['country']
# ['runtime', 'language']
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language']
# ['country']
# ['rated']
# ['genre']
# ['runtime']
# ['genre']
# ['language']
# ['rated']
# ['country']
# ['country']
# ['language']
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language', 'country']
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# ['language']
# ['rated']
# ['country']
# ['country']
# ['runtime']
# ['country', 'rated']
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language', 'country']
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['language']
# ['rated']
# ['country']
# ['country']
# ['language', 'country']
# ['runtime', 'language']
# ['language', 'country']
# ['country', 'rated']
# ['language']
# ['language', 'country']
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['language']
# ['rated']
# ['country']
# ['runtime', 'language']
# ['runtime', 'language']
# ['language', 'country']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['country', 'rated']
# ['language']
# ['language', 'country']
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Pia\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ['runtime', 'language']
# ['genre', 'year']
# ['genre']
# ['language']
# ['rated']
# ['country']
# ['runtime', 'language']
#                      classifier      used_features  precision    recall  \
# classifier        decision_tree                all   0.595595  0.616667
# classifier                  knn        genre, year   0.666310  0.666667
# classifier         nearest_mean  runtime, language   0.623690  0.610000
# classifier  logistic_regression  runtime, language   0.596032  0.730000
# classifier                  svm           language   0.547980  1.000000
# classifier              bagging     country, rated   0.592857  0.593333
# classifier        random_forest  language, country   0.657897  0.596667
# classifier             adaboost  runtime, language   0.725833  0.633333
# classifier       gradient_boost  runtime, language   0.709167  0.673333
#
#                   f1
# classifier  0.593802
# classifier  0.639066
# classifier  0.601805
# classifier  0.652597
# classifier  0.707843
# classifier  0.580730
# classifier  0.590458
# classifier  0.646378
# classifier  0.647529

# %%
#def check_unique_entries(df, sort=True):
#    # columns.remove('title')
#    for column in df.columns:
#        unique_entries = df[column].unique()
#        if sort:
#            unique_entries.sort()
#        print(column, len(unique_entries), '\n', unique_entries)

#df_train.runtime = df_train.runtime.apply(lambda x: x[:-4])
#df_train.BoxOffice = df_train.BoxOffice.apply(lambda x: x if x!=x else x[1:-3] + x[len(x)-2:])
#df_train.BoxOffice = df_train.BoxOffice.apply(lambda x: x if x!=x else x[:-1] + '0'*5 if x[-1]=='M' else x[:-1] + '0'*2)
#df_train.BoxOffice

#df_train.drop(['released', 'metascore', 'imdbRating', 'imdbVotes', 'tomatoMeter', 'tomatoRating'])

#df_to_int = df_train.loc[:, ['year', 'runtime', 'metascore', 'imdbVotes', 'tomatoMeter', 'tomatoReviews', 'tomatoFresh', 
#                          'tomatoRotten', 'tomatoUserMeter', 'tomatoUserReviews', 'BoxOffice']]

#def df_from_xml(data_set, columns):
#    df = pd.DataFrame(columns = columns)
#    for movie_name in os.listdir(data_set + '_Set/XML'):  
#        xtree = et.parse(data_set + '_Set/XML/' + movie_name)
#        xroot = xtree.getroot()
#        instance = []
#        for element in columns:
#            if xroot[0] is not None: # and element != 'goodforairplane': # feature "good for airplane" is not filled in 
#                instance.append(xroot.find('movie').get(element))
#            else:
#                pass
#        if len(instance) < len(columns):
#            instance.append(movie_name[:-3])
#        my_series = pd.Series(instance, index = columns)
#        df = df.append(my_series, ignore_index=True)
#    # labels_to_drop = ['director', 'writer', 'actors', 'plot', 'awards', 'poster', 'tomatoConsensus', 'Website', 'imdbID', 'type']
#    # df_train.replace('N/A', np.nan, inplace=True)
#    return df
#
## df_test = df_from_xml('Test')
## df = df_dev.append(df_test, ignore_index=True)
#df = df.loc[:, ['title', 'language', 'year', 'genre', 'country', 'runtime', 'rated']]
#df.runtime = df.runtime.apply(lambda x: x[:-4])
#df.rated.replace(['NOT RATED', 'UNRATED'], 'N/A', inplace=True)
#df.year = pd.to_numeric(df.year, errors='coerce')
#df.runtime = pd.to_numeric(df.runtime, errors='coerce')
#    
##df_dev = df.iloc[:95]
##df_test = df.iloc[95:]
#labels = pd.read_excel(r'Dev_Set\dev_set_groundtruth_and_trailers.xls', index_col=0).goodforairplane
## labels_test = pd.read_csv(r'Test_Set\CoeTestLabels.csv', index_col=0).goodforairplanes
#df.set_index('title', inplace=True)
## df_dev = df_dev.merge(labels_dev, left_index=True, right_index=True)
## df_test.set_index('title', inplace=True)
## df_test = df_test.merge(labels_test, left_index=True, right_index=True)
## df_test.shape
