# %%
from os import chdir
chdir(r'C:\Users\Pia\OneDrive\Data Science\experiment_design\ex_2\CoE_dataset')
import xml.etree.ElementTree as et

from random import seed, sample, choice
import numpy as np
import pandas as pd
pd.options.display.max_columns = 34
pd.options.display.max_rows = 100

from metadata_ratings_helper_functions import load_data, get_dummies

from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier

# %% [markdown]
# ## Use this chunk of code for loading the training data
# We'll do one-hot encoding after feature selection

# %%
df = load_data('Dev').loc[:, ['language', 'year', 'genre', 'country', 'runtime', 'rated']]
df_test = load_data('Test').loc[:, ['language', 'year', 'genre', 'country', 'runtime', 'rated']]

labels = pd.read_excel(r'Dev_Set\dev_set_groundtruth_and_trailers.xls', index_col=0).goodforairplane

df_test.head(100)
# Out:
#                                                                                              language  \
# title
# 10.000 Km                                                                   Spanish, Catalan, English
# 12 Years a Slave                                                                              English
# 21 Jump Street                                                                                English
# 2 States                                                                                        Hindi
# Aanmodderfakker                                                                                 Dutch
# Alexander                                                                                     English
# Alexander and the Terrible, Horrible, No Good, ...                                            English
# Alice in Wonderland                                                                           English
# American Sniper                                                                               English
# Anastasia                                                                    English, Russian, French
# And So It Goes                                                                                English
# Antz                                                                                          English
# Avatar                                                                               English, Spanish
# A Bug's Life                                                                                  English
# A Little Chaos                                                                                English
# A Most Wanted Man                                                                    English, Turkish
# A Simple Life                                                            Cantonese, English, Mandarin
# Bad News Bears                                                                       English, Spanish
# Banklady                                                                                       German
# Beetlejuice                                                                                   English
# Begin Again                                                                                   English
# Belle de Jour                                                              French, Spanish, Mongolian
# Bewakoofiyaan                                                                          Hindi, English
# Bhoothnath                                                                                      Hindi
# Big Game                                                                                      English
# Billy Elliot                                                                                  English
# Birdman: Or (The Unexpected Virtue of Ignorance)                                              English
# Blended                                                                                       English
# Blow Out                                                                                      English
# Bride Flight                                                                           Dutch, English
# Bridges of Sarajevo                                 Russian, German, Italian, French, Bosnian, Cat...
# Burlesque                                                                                     English
# Captain America: The Winter Soldier                                                           English
# Cascadeur                                                                                      German
# Charlie and the Chocolate Factory                                                             English
# Clash of the Titans                                                                           English
# Contact                                                             English, Spanish, German, Russian
# Dances with Wolves                                                             English, Sioux, Pawnee
# Dilwale Dulhania Le Jayenge                                             Hindi, Urdu, English, Panjabi
# Divergent                                                                            English, Spanish
# Django Unchained                                                              English, German, French
# Dolphin Tale 2                                                                                English
# Dorsvloer vol confetti                                                                          Dutch
# Dracula Untold                                                                                English
# Dumbo                                                                                         English
# Dumb and Dumber To                                                                            English
# Edge of Tomorrow                                                                              English
# Fargo                                                                                         English
# Fast Five                                                       English, Portuguese, Spanish, Italian
# Finding Fanny                                                                 Hindi, English, Konkani
# Finding Nemo                                                                                  English
# Flying Home                                                                            Dutch, English
# Foxcatcher                                                                            English, French
# From A to B                                                                           Arabic, English
# Frozen                                                                             English, Icelandic
# Fury                                                                                  English, German
# Godzilla                                                                            English, Japanese
# Gone Girl                                                                                     English
# Good Morning, Vietnam                                                                         English
# Good People                                                                                   English
# Good Will Hunting                                                                             English
# Gooische vrouwen                                                                                Dutch
# Gran Torino                                                                            English, Hmong
# Groundhog Day                                                                English, French, Italian
# Guardians of the Galaxy                                                                       English
# Gunday                                                                                 Hindi, Bengali
# Happy New Year                                                                                  Hindi
# Harry Potter and the Deathly Hallows: Part 2                                                  English
# Heaven Knows What                                                                             English
# Hector and the Search for Happiness                                           English, French, German
# Hercules                                                                      English, Spanish, Greek
# Homeland                                                                                      English
# Horrible Bosses 2                                                                             English
# How to Train Your Dragon 2                                                                    English
# Humpty Sharma Ki Dulhania                                                                       Hindi
# Hum Aapke Hain Koun...!                                                                   Hindi, Urdu
# Hungry Hearts                                                                                 English
# Interview with the Vampire: The Vampire Chronicles                                    English, French
# In Her Shoes                                                                                  English
# Ironclad                                                            English, Hungarian, Latin, Danish
# Iron Man 2                                                                   English, French, Russian
# Iron Man 3                                                                                    English
# I Am Big Bird: The Caroll Spinney Story                                                       English
# John Tucker Must Die                                                                          English
# Justin Bieber: Never Say Never                                                                English
# Karan Arjun                                                                                     Hindi
# Katalin Varga                                                                     Hungarian, Romanian
# Kick-Ass                                                                                      English
# Kick-Ass 2                                                                                    English
# Kingsman: The Secret Service                                                 English, Arabic, Swedish
# Kundo: Age of the Rampant                                                                      Korean
# Kurt Cobain: Montage of Heck                                                                  English
# La Camioneta: The Journey of One American Schoo...                                   English, Spanish
# La foresta di ghiaccio                                                                        Italian
# La Vie en Rose                                                                        French, English
# Legally Blonde                                                                                English
# Leviathan                                                                                     Russian
# Life of Crime                                                                                 English
# Lilting                                                                             English, Mandarin
# Limitless                                                 English, Russian, Italian, Mandarin, French
#
#                                                     year  \
# title
# 10.000 Km                                           2014
# 12 Years a Slave                                    2013
# 21 Jump Street                                      2012
# 2 States                                            2014
# Aanmodderfakker                                     2014
# Alexander                                           2004
# Alexander and the Terrible, Horrible, No Good, ...  2014
# Alice in Wonderland                                 2010
# American Sniper                                     2014
# Anastasia                                           1997
# And So It Goes                                      2014
# Antz                                                1998
# Avatar                                              2009
# A Bug's Life                                        1998
# A Little Chaos                                      2014
# A Most Wanted Man                                   2014
# A Simple Life                                       2011
# Bad News Bears                                      2005
# Banklady                                            2013
# Beetlejuice                                         1988
# Begin Again                                         2013
# Belle de Jour                                       1967
# Bewakoofiyaan                                       2014
# Bhoothnath                                          2008
# Big Game                                            2014
# Billy Elliot                                        2000
# Birdman: Or (The Unexpected Virtue of Ignorance)    2014
# Blended                                             2014
# Blow Out                                            1981
# Bride Flight                                        2008
# Bridges of Sarajevo                                 2014
# Burlesque                                           2010
# Captain America: The Winter Soldier                 2014
# Cascadeur                                           1998
# Charlie and the Chocolate Factory                   2005
# Clash of the Titans                                 2010
# Contact                                             1997
# Dances with Wolves                                  1990
# Dilwale Dulhania Le Jayenge                         1995
# Divergent                                           2014
# Django Unchained                                    2012
# Dolphin Tale 2                                      2014
# Dorsvloer vol confetti                              2014
# Dracula Untold                                      2014
# Dumbo                                               1941
# Dumb and Dumber To                                  2014
# Edge of Tomorrow                                    2014
# Fargo                                               1996
# Fast Five                                           2011
# Finding Fanny                                       2014
# Finding Nemo                                        2003
# Flying Home                                         2014
# Foxcatcher                                          2014
# From A to B                                         2014
# Frozen                                              2013
# Fury                                                2014
# Godzilla                                            2014
# Gone Girl                                           2014
# Good Morning, Vietnam                               1987
# Good People                                         2014
# Good Will Hunting                                   1997
# Gooische vrouwen                                    2011
# Gran Torino                                         2008
# Groundhog Day                                       1993
# Guardians of the Galaxy                             2014
# Gunday                                              2014
# Happy New Year                                      2014
# Harry Potter and the Deathly Hallows: Part 2        2011
# Heaven Knows What                                   2014
# Hector and the Search for Happiness                 2014
# Hercules                                            1997
# Homeland                                            2011
# Horrible Bosses 2                                   2014
# How to Train Your Dragon 2                          2014
# Humpty Sharma Ki Dulhania                           2014
# Hum Aapke Hain Koun...!                             1994
# Hungry Hearts                                       2014
# Interview with the Vampire: The Vampire Chronicles  1994
# In Her Shoes                                        2005
# Ironclad                                            2011
# Iron Man 2                                          2010
# Iron Man 3                                          2013
# I Am Big Bird: The Caroll Spinney Story             2014
# John Tucker Must Die                                2006
# Justin Bieber: Never Say Never                      2011
# Karan Arjun                                         1995
# Katalin Varga                                       2009
# Kick-Ass                                            2010
# Kick-Ass 2                                          2013
# Kingsman: The Secret Service                        2014
# Kundo: Age of the Rampant                           2014
# Kurt Cobain: Montage of Heck                        2015
# La Camioneta: The Journey of One American Schoo...  2012
# La foresta di ghiaccio                              2014
# La Vie en Rose                                      2007
# Legally Blonde                                      2001
# Leviathan                                           2014
# Life of Crime                                       2013
# Lilting                                             2014
# Limitless                                           2011
#
#                                                                             genre  \
# title
# 10.000 Km                                                  Comedy, Drama, Romance
# 12 Years a Slave                                        Biography, Drama, History
# 21 Jump Street                                              Action, Comedy, Crime
# 2 States                                                   Comedy, Drama, Romance
# Aanmodderfakker                                                   Comedy, Romance
# Alexander                                            Action, Adventure, Biography
# Alexander and the Terrible, Horrible, No Good, ...                 Comedy, Family
# Alice in Wonderland                                    Adventure, Family, Fantasy
# American Sniper                                       Action, Biography, Thriller
# Anastasia                                             Animation, Adventure, Drama
# And So It Goes                                             Comedy, Drama, Romance
# Antz                                                 Animation, Adventure, Comedy
# Avatar                                                 Action, Adventure, Fantasy
# A Bug's Life                                         Animation, Adventure, Comedy
# A Little Chaos                                             Comedy, Drama, Romance
# A Most Wanted Man                                                        Thriller
# A Simple Life                                                               Drama
# Bad News Bears                                              Comedy, Family, Sport
# Banklady                                                 Action, Biography, Crime
# Beetlejuice                                                                Comedy
# Begin Again                                                          Drama, Music
# Belle de Jour                                                               Drama
# Bewakoofiyaan                                              Comedy, Drama, Romance
# Bhoothnath                                                 Comedy, Drama, Fantasy
# Big Game                                                        Action, Adventure
# Billy Elliot                                                 Comedy, Drama, Music
# Birdman: Or (The Unexpected Virtue of Ignorance)                    Comedy, Drama
# Blended                                                           Comedy, Romance
# Blow Out                                                 Drama, Mystery, Thriller
# Bride Flight                                                                Drama
# Bridges of Sarajevo                                                         Drama
# Burlesque                                                   Drama, Music, Romance
# Captain America: The Winter Soldier                     Action, Adventure, Sci-Fi
# Cascadeur                                                       Action, Adventure
# Charlie and the Chocolate Factory                       Adventure, Comedy, Family
# Clash of the Titans                                    Action, Adventure, Fantasy
# Contact                                                    Drama, Mystery, Sci-Fi
# Dances with Wolves                                      Adventure, Drama, Western
# Dilwale Dulhania Le Jayenge                                Comedy, Drama, Musical
# Divergent                                             Adventure, Sci-Fi, Thriller
# Django Unchained                                                          Western
# Dolphin Tale 2                                                      Drama, Family
# Dorsvloer vol confetti                                                      Drama
# Dracula Untold                                             Action, Drama, Fantasy
# Dumbo                                                  Animation, Family, Musical
# Dumb and Dumber To                                                         Comedy
# Edge of Tomorrow                                                   Action, Sci-Fi
# Fargo                                                      Crime, Drama, Thriller
# Fast Five                                                 Action, Crime, Thriller
# Finding Fanny                                              Comedy, Drama, Romance
# Finding Nemo                                         Animation, Adventure, Comedy
# Flying Home                                                               Romance
# Foxcatcher                                                Biography, Drama, Sport
# From A to B                                              Adventure, Comedy, Drama
# Frozen                                               Animation, Adventure, Comedy
# Fury                                                           Action, Drama, War
# Godzilla                                                Action, Adventure, Sci-Fi
# Gone Girl                                                Drama, Mystery, Thriller
# Good Morning, Vietnam                                          Comedy, Drama, War
# Good People                                               Action, Crime, Thriller
# Good Will Hunting                                                           Drama
# Gooische vrouwen                                                    Comedy, Drama
# Gran Torino                                                                 Drama
# Groundhog Day                                            Comedy, Fantasy, Romance
# Guardians of the Galaxy                                 Action, Adventure, Sci-Fi
# Gunday                                                       Action, Crime, Drama
# Happy New Year                                              Action, Comedy, Crime
# Harry Potter and the Deathly Hallows: Part 2          Adventure, Fantasy, Mystery
# Heaven Knows What                                                           Drama
# Hector and the Search for Happiness                      Adventure, Comedy, Drama
# Hercules                                             Animation, Adventure, Comedy
# Homeland                                                 Drama, Mystery, Thriller
# Horrible Bosses 2                                                   Comedy, Crime
# How to Train Your Dragon 2                           Animation, Action, Adventure
# Humpty Sharma Ki Dulhania                                  Comedy, Drama, Romance
# Hum Aapke Hain Koun...!                                    Comedy, Drama, Musical
# Hungry Hearts                                                     Drama, Thriller
# Interview with the Vampire: The Vampire Chronicles                Horror, Romance
# In Her Shoes                                               Comedy, Drama, Romance
# Ironclad                                               Action, Adventure, History
# Iron Man 2                                              Action, Adventure, Sci-Fi
# Iron Man 3                                              Action, Adventure, Sci-Fi
# I Am Big Bird: The Caroll Spinney Story             Documentary, Biography, Drama
# John Tucker Must Die                                              Comedy, Romance
# Justin Bieber: Never Say Never                                 Documentary, Music
# Karan Arjun                                               Action, Comedy, Fantasy
# Katalin Varga                                              Crime, Drama, Thriller
# Kick-Ass                                                           Action, Comedy
# Kick-Ass 2                                                  Action, Comedy, Crime
# Kingsman: The Secret Service                            Action, Adventure, Comedy
# Kundo: Age of the Rampant                                           Action, Drama
# Kurt Cobain: Montage of Heck                        Documentary, Biography, Music
# La Camioneta: The Journey of One American Schoo...                    Documentary
# La foresta di ghiaccio                                                   Thriller
# La Vie en Rose                                            Biography, Drama, Music
# Legally Blonde                                                    Comedy, Romance
# Leviathan                                                                   Drama
# Life of Crime                                                       Comedy, Crime
# Lilting                                                            Drama, Romance
# Limitless                                               Mystery, Sci-Fi, Thriller
#
#                                                                                               country  \
# title
# 10.000 Km                                                                                       Spain
# 12 Years a Slave                                                                              USA, UK
# 21 Jump Street                                                                                    USA
# 2 States                                                                                        India
# Aanmodderfakker                                                                           Netherlands
# Alexander                                                Germany, USA, Netherlands, France, UK, Italy
# Alexander and the Terrible, Horrible, No Good, ...                                                USA
# Alice in Wonderland                                                                               USA
# American Sniper                                                                                   USA
# Anastasia                                                                             USA, Canada, UK
# And So It Goes                                                                                    USA
# Antz                                                                                              USA
# Avatar                                                                                        USA, UK
# A Bug's Life                                                                                      USA
# A Little Chaos                                                                                     UK
# A Most Wanted Man                                                                    UK, USA, Germany
# A Simple Life                                                                               Hong Kong
# Bad News Bears                                                                                    USA
# Banklady                                                                                      Germany
# Beetlejuice                                                                                       USA
# Begin Again                                                                                       USA
# Belle de Jour                                                                           France, Italy
# Bewakoofiyaan                                                                                   India
# Bhoothnath                                                                                      India
# Big Game                                                                         Finland, UK, Germany
# Billy Elliot                                                                               UK, France
# Birdman: Or (The Unexpected Virtue of Ignorance)                                                  USA
# Blended                                                                                           USA
# Blow Out                                                                                          USA
# Bride Flight                                                                  Netherlands, Luxembourg
# Bridges of Sarajevo                                 France, Bosnia and Herzegovina, Switzerland, I...
# Burlesque                                                                                         USA
# Captain America: The Winter Soldier                                                               USA
# Cascadeur                                                                                     Germany
# Charlie and the Chocolate Factory                                                  USA, UK, Australia
# Clash of the Titans                                                                               USA
# Contact                                                                                           USA
# Dances with Wolves                                                                            USA, UK
# Dilwale Dulhania Le Jayenge                                                                     India
# Divergent                                                                                         USA
# Django Unchained                                                                                  USA
# Dolphin Tale 2                                                                                    USA
# Dorsvloer vol confetti                                                           Netherlands, Belgium
# Dracula Untold                                                                                    USA
# Dumbo                                                                                             USA
# Dumb and Dumber To                                                                                USA
# Edge of Tomorrow                                                                          USA, Canada
# Fargo                                                                                         USA, UK
# Fast Five                                                                                         USA
# Finding Fanny                                                                                   India
# Finding Nemo                                                                                      USA
# Flying Home                                                                          Belgium, Germany
# Foxcatcher                                                                                        USA
# From A to B                                                                      United Arab Emirates
# Frozen                                                                                            USA
# Fury                                                                                   USA, China, UK
# Godzilla                                                                                   USA, Japan
# Gone Girl                                                                                         USA
# Good Morning, Vietnam                                                                             USA
# Good People                                                                  UK, USA, Sweden, Denmark
# Good Will Hunting                                                                                 USA
# Gooische vrouwen                                                                          Netherlands
# Gran Torino                                                                              USA, Germany
# Groundhog Day                                                                                     USA
# Guardians of the Galaxy                                                                       USA, UK
# Gunday                                                                                          India
# Happy New Year                                                                                  India
# Harry Potter and the Deathly Hallows: Part 2                                                  USA, UK
# Heaven Knows What                                                                                 USA
# Hector and the Search for Happiness                                 Germany, Canada, UK, South Africa
# Hercules                                                                                          USA
# Homeland                                                                                          USA
# Horrible Bosses 2                                                                                 USA
# How to Train Your Dragon 2                                                                        USA
# Humpty Sharma Ki Dulhania                                                                       India
# Hum Aapke Hain Koun...!                                                                         India
# Hungry Hearts                                                                                   Italy
# Interview with the Vampire: The Vampire Chronicles                                                USA
# In Her Shoes                                                                         USA, Germany, UK
# Ironclad                                                                UK, Switzerland, USA, Germany
# Iron Man 2                                                                                        USA
# Iron Man 3                                                                                 USA, China
# I Am Big Bird: The Caroll Spinney Story                                                           USA
# John Tucker Must Die                                                                      USA, Canada
# Justin Bieber: Never Say Never                                                                    USA
# Karan Arjun                                                                                     India
# Katalin Varga                                                                             Romania, UK
# Kick-Ass                                                                                      UK, USA
# Kick-Ass 2                                                                             USA, UK, Japan
# Kingsman: The Secret Service                                                                       UK
# Kundo: Age of the Rampant                                                                 South Korea
# Kurt Cobain: Montage of Heck                                                                      USA
# La Camioneta: The Journey of One American Schoo...                                     USA, Guatemala
# La foresta di ghiaccio                                                                          Italy
# La Vie en Rose                                                     France, UK, Czech Republic, Canada
# Legally Blonde                                                                                    USA
# Leviathan                                                                                      Russia
# Life of Crime                                                                                     USA
# Lilting                                                                                            UK
# Limitless                                                                                         USA
#
#                                                     runtime     rated
# title
# 10.000 Km                                              99.0         R
# 12 Years a Slave                                      134.0         R
# 21 Jump Street                                        109.0         R
# 2 States                                              149.0       N/A
# Aanmodderfakker                                       100.0       N/A
# Alexander                                             175.0         R
# Alexander and the Terrible, Horrible, No Good, ...     81.0        PG
# Alice in Wonderland                                   108.0        PG
# American Sniper                                       132.0         R
# Anastasia                                              94.0         G
# And So It Goes                                         94.0     PG-13
# Antz                                                   83.0        PG
# Avatar                                                162.0     PG-13
# A Bug's Life                                           95.0         G
# A Little Chaos                                        117.0         R
# A Most Wanted Man                                     122.0         R
# A Simple Life                                         118.0       N/A
# Bad News Bears                                        113.0     PG-13
# Banklady                                              118.0       N/A
# Beetlejuice                                            92.0        PG
# Begin Again                                           104.0         R
# Belle de Jour                                         101.0  APPROVED
# Bewakoofiyaan                                         119.0       N/A
# Bhoothnath                                            150.0       N/A
# Big Game                                              110.0     PG-13
# Billy Elliot                                          110.0     PG-13
# Birdman: Or (The Unexpected Virtue of Ignorance)      119.0         R
# Blended                                               117.0     PG-13
# Blow Out                                              107.0         R
# Bride Flight                                          130.0         R
# Bridges of Sarajevo                                   114.0       N/A
# Burlesque                                             119.0     PG-13
# Captain America: The Winter Soldier                   136.0     PG-13
# Cascadeur                                             106.0       N/A
# Charlie and the Chocolate Factory                     115.0        PG
# Clash of the Titans                                   106.0     PG-13
# Contact                                               150.0        PG
# Dances with Wolves                                    181.0     PG-13
# Dilwale Dulhania Le Jayenge                           181.0       N/A
# Divergent                                             139.0     PG-13
# Django Unchained                                      165.0         R
# Dolphin Tale 2                                        107.0        PG
# Dorsvloer vol confetti                                 94.0       N/A
# Dracula Untold                                         92.0     PG-13
# Dumbo                                                  64.0  APPROVED
# Dumb and Dumber To                                    109.0     PG-13
# Edge of Tomorrow                                      113.0     PG-13
# Fargo                                                  98.0         R
# Fast Five                                             131.0     PG-13
# Finding Fanny                                         102.0       N/A
# Finding Nemo                                          100.0         G
# Flying Home                                            95.0       N/A
# Foxcatcher                                            134.0         R
# From A to B                                           108.0       N/A
# Frozen                                                102.0        PG
# Fury                                                  134.0         R
# Godzilla                                              123.0     PG-13
# Gone Girl                                             149.0         R
# Good Morning, Vietnam                                 121.0         R
# Good People                                            90.0         R
# Good Will Hunting                                     126.0         R
# Gooische vrouwen                                      105.0       N/A
# Gran Torino                                           116.0         R
# Groundhog Day                                         101.0        PG
# Guardians of the Galaxy                               121.0     PG-13
# Gunday                                                152.0       N/A
# Happy New Year                                        180.0       N/A
# Harry Potter and the Deathly Hallows: Part 2          130.0     PG-13
# Heaven Knows What                                      94.0         R
# Hector and the Search for Happiness                   114.0         R
# Hercules                                               93.0         G
# Homeland                                               55.0     TV-MA
# Horrible Bosses 2                                     108.0         R
# How to Train Your Dragon 2                            102.0        PG
# Humpty Sharma Ki Dulhania                             133.0       N/A
# Hum Aapke Hain Koun...!                               206.0       N/A
# Hungry Hearts                                         109.0       N/A
# Interview with the Vampire: The Vampire Chronicles    123.0         R
# In Her Shoes                                          130.0     PG-13
# Ironclad                                              121.0         R
# Iron Man 2                                            124.0     PG-13
# Iron Man 3                                            130.0     PG-13
# I Am Big Bird: The Caroll Spinney Story                90.0       N/A
# John Tucker Must Die                                   89.0     PG-13
# Justin Bieber: Never Say Never                        105.0         G
# Karan Arjun                                           175.0       N/A
# Katalin Varga                                          82.0       N/A
# Kick-Ass                                              117.0         R
# Kick-Ass 2                                            103.0         R
# Kingsman: The Secret Service                          129.0         R
# Kundo: Age of the Rampant                             137.0       N/A
# Kurt Cobain: Montage of Heck                          145.0     TV-MA
# La Camioneta: The Journey of One American Schoo...      NaN       N/A
# La foresta di ghiaccio                                 99.0       N/A
# La Vie en Rose                                        140.0     PG-13
# Legally Blonde                                         96.0     PG-13
# Leviathan                                             140.0         R
# Life of Crime                                          98.0         R
# Lilting                                                91.0       N/A
# Limitless                                             105.0     PG-13

# %% [markdown]
# ## Use this for computing the metrics:

# %%
def get_clf(classifier):
        
    if classifier == 'knn':
        return KNeighborsClassifier()
        
    elif classifier == 'nearest_mean':
        return NearestCentroid()
        
    elif classifier == 'decision_tree':
        return DecisionTreeClassifier()
        
    elif classifier == 'logistic_regression':
        return LogisticRegression(solver='lbfgs')  # for not getting warnings
        
    elif classifier == 'svm':
        return SVC(kernel = 'rbf', gamma='auto')  # for avoiding warnings    
            
    elif classifier == 'bagging':
        return BaggingClassifier()
        
    elif classifier == 'random_forest':
        return RandomForestClassifier(n_estimators=10)  # for not getting warnings
        
    elif classifier == 'adaboost':
        return AdaBoostClassifier()
        
    elif classifier == 'gradient_boost':
        return GradientBoostingClassifier()
    

def compute_scores(X, y, classifier):    
    
    np.random.seed(1)  # scikit-learn uses numpy.random
    return cross_validate(get_clf(classifier), X, y, cv = 10, scoring = ['precision', 'recall', 'f1'])


def compute_preds(X, y, X_test, classifier, S):
    X_best = X.copy().loc[:, S]
    X_best = get_dummies(X_best, S)
    
    np.random.seed(1)
    preds_cv = cross_val_predict(get_clf(classifier), X_best, y, cv=10)
    
    clf = get_clf(classifier)
    clf.fit(X_best, y)
    
    X_best_test = X_test.copy().loc[:, S]
    X_best_test = get_dummies(X_best_test, S)
    
    preds = clf.predict(X_best_test)

    return preds_cv, preds

# %%
# something is still not working, if you run this chunk of code a second time, the features, that are elected are less and the 
# scores are lower
    
def LVW(X, y, X_test, K, classifier):
     
    original_features = list(X.columns)    
    f1_best = 0
    k = 0
    C = len(original_features)
        
    seed(1)  # seed for package 'random'
    while k < K:
        sample_sizes = range(1, C + 1)
        my_choice = choice(sample_sizes)
        S1 = sample(original_features, my_choice)
        C1 = len(S1)
        
        # take a subset of the original dataframe X:
        X1 = X.copy().loc[:, S1]
        
        X1 = get_dummies(X1, S1)
        
        scores = compute_scores(X1, y, classifier)
        f1 = np.mean(scores['test_f1'])
        
        if (f1 > f1_best) or (f1 == f1_best and C1 < C):
            k, f1_best, C, S  = 0, f1, C1, S1
            precision, recall = np.mean(scores['test_precision']), np.mean(scores['test_recall'])
        else:
            k += 1
        
    # get a string: 
    used_features = S[0]
    for feature in S[1:]:
        used_features += ', ' + feature
    

    predictions_cv, predictions = compute_preds(X, y, X_test, classifier, S)

    return pd.DataFrame({'classifier': [classifier], 'used_features': [used_features], 'precision': [precision], 
                         'recall': [recall], 'f1': f1_best}, index=['classifier']), predictions_cv, predictions



# as the decision tree does not need the LVW, we compute it first without the LVW: 
df_with_dummies = get_dummies(df)
df_with_dummies_test = get_dummies(df_test)
df_with_dummies_test = df_with_dummies_test.fillna(df_with_dummies_test.mean())
scores_tree = compute_scores(df_with_dummies, labels, 'decision_tree')

scores = pd.DataFrame({'classifier': ['decision_tree'], 'used_features': ['all'], 
                       'precision': [np.mean(scores_tree['test_precision'])], 
                       'recall': [np.mean(scores_tree['test_recall'])], 'f1': np.mean(scores_tree['test_f1'])},
                        index=['classifier'])

preds_tree, preds_tree_test = compute_preds(df_with_dummies, labels, df_with_dummies_test, 'decision_tree', df_with_dummies.columns)
preds = pd.DataFrame(preds_tree, index=labels.index, columns=['decision_tree'])

for clf in ['knn', 'nearest_mean', 'logistic_regression', 'svm', 'bagging', 'random_forest', 'adaboost', 'gradient_boost']: 
    scores_tmp, preds_cv_tmp, preds_tmp = LVW(df, labels, df_test, 10, clf)
    scores = scores.append(scores_tmp)
    preds = preds.merge(pd.DataFrame(preds_cv_tmp, index=labels.index, columns=[clf]), 
                        left_index=True, right_index=True)
    
preds.to_csv('predictions_metadata_dev.csv')
preds
# Out:
# C:\Users\Pia\Anaconda3\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-442aea3c2778> in <module>
#      54                         index=['classifier'])
#      55
# ---> 56 preds_tree, preds_tree_test = compute_preds(df_with_dummies, labels, df_with_dummies_test, 'decision_tree', df_with_dummies.columns)
#      57 preds = pd.DataFrame(preds_tree, index=labels.index, columns=['decision_tree'])
#      58
#
# <ipython-input-56-4a73e1be3693> in compute_preds(X, y, X_test, classifier, S)
#      48     X_best_test = get_dummies(X_best_test, S)
#      49
# ---> 50     preds = clf.predict(X_best_test)
#      51
#      52     return preds_cv, preds
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     428         """
#     429         check_is_fitted(self, 'tree_')
# --> 430         X = self._validate_X_predict(X, check_input)
#     431         proba = self.tree_.predict(X)
#     432         n_samples = X.shape[0]
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     389         """Validate X whenever one tries to predict, apply, predict_proba"""
#     390         if check_input:
# --> 391             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     392             if issparse(X) and (X.indices.dtype != np.intc or
#     393                                 X.indptr.dtype != np.intc):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     540         if force_all_finite:
#     541             _assert_all_finite(array,
# --> 542                                allow_nan=force_all_finite == 'allow-nan')
#     543
#     544     if ensure_min_samples > 0:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57     # for object dtype data, we only check for NaNs (GH-13254)
#      58     elif X.dtype == np.dtype('object') and not allow_nan:
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
## afterwards we'll do the same thing for the test set
#data_set = 'Dev'
#
## get the columnnames:
#xtree = et.parse(r'Dev_Set\XML\A_Fish_Called_Wanda.xml')
#xroot = xtree.getroot()
#columns = list(xroot.find('movie').keys())
#df = pd.DataFrame(columns = columns)
#
#for movie_name in os.listdir(data_set + '_Set/XML'):  
#    xtree = et.parse(data_set + '_Set/XML/' + movie_name)
#    xroot = xtree.getroot()
#    instance = []
#    for element in columns:
#        if xroot[0] is not None: # and element != 'goodforairplane': # feature "good for airplane" is not filled in 
#            instance.append(xroot.find('movie').get(element))
#        else:
#            pass
#    if len(instance) < len(columns):
#        instance.append(movie_name[:-3])
#    my_series = pd.Series(instance, index = columns)
#    df = df.append(my_series, ignore_index=True)
#
#df.set_index('title', inplace=True)
#
#df = df.loc[:, ['language', 'year', 'genre', 'country', 'runtime', 'rated']]
#
## make the feature 'runtime' numeric:
#df.runtime = df.runtime.apply(lambda x: x[:-4])
#df.runtime = pd.to_numeric(df.runtime, errors='coerce')
#
## bring the entries of 'rated' which were not filled out into a unique shape:
#df.rated.replace(['NOT RATED', 'UNRATED'], 'N/A', inplace=True)
#
#df.year = pd.to_numeric(df.year, errors='coerce')
#
#labels = pd.read_excel(r'Dev_Set\dev_set_groundtruth_and_trailers.xls', index_col=0).goodforairplane
#df.head(100)





#def get_dummies(df, selected_features=['language', 'genre', 'country', 'rated']):
#    
#    df_tmp = df.copy()
#    for feature in set(selected_features).intersection(['language', 'genre', 'country', 'rated']):  # we only get dummy 
#                                                                                                     # variables for categorical
#                                                                                                      # data
#        # split the variables with various entries: 
#        one_hot = df.copy().loc[:, feature].str.split(', ', expand=True).stack()
#        
#        one_hot = pd.get_dummies(one_hot, prefix=feature, drop_first=True).groupby(level=0).sum()
#        df_tmp = df_tmp.drop(feature, axis=1)
#        df_tmp = df_tmp.merge(one_hot, left_index=True, right_index=True)
#    
#    return df_tmp

# %%
#def check_unique_entries(df, sort=True):
#    # columns.remove('title')
#    for column in df.columns:
#        unique_entries = df[column].unique()
#        if sort:
#            unique_entries.sort()
#        print(column, len(unique_entries), '\n', unique_entries)

#df_train.runtime = df_train.runtime.apply(lambda x: x[:-4])
#df_train.BoxOffice = df_train.BoxOffice.apply(lambda x: x if x!=x else x[1:-3] + x[len(x)-2:])
#df_train.BoxOffice = df_train.BoxOffice.apply(lambda x: x if x!=x else x[:-1] + '0'*5 if x[-1]=='M' else x[:-1] + '0'*2)
#df_train.BoxOffice

#df_train.drop(['released', 'metascore', 'imdbRating', 'imdbVotes', 'tomatoMeter', 'tomatoRating'])

#df_to_int = df_train.loc[:, ['year', 'runtime', 'metascore', 'imdbVotes', 'tomatoMeter', 'tomatoReviews', 'tomatoFresh', 
#                          'tomatoRotten', 'tomatoUserMeter', 'tomatoUserReviews', 'BoxOffice']]

#def df_from_xml(data_set, columns):
#    df = pd.DataFrame(columns = columns)
#    for movie_name in os.listdir(data_set + '_Set/XML'):  
#        xtree = et.parse(data_set + '_Set/XML/' + movie_name)
#        xroot = xtree.getroot()
#        instance = []
#        for element in columns:
#            if xroot[0] is not None: # and element != 'goodforairplane': # feature "good for airplane" is not filled in 
#                instance.append(xroot.find('movie').get(element))
#            else:
#                pass
#        if len(instance) < len(columns):
#            instance.append(movie_name[:-3])
#        my_series = pd.Series(instance, index = columns)
#        df = df.append(my_series, ignore_index=True)
#    # labels_to_drop = ['director', 'writer', 'actors', 'plot', 'awards', 'poster', 'tomatoConsensus', 'Website', 'imdbID', 'type']
#    # df_train.replace('N/A', np.nan, inplace=True)
#    return df
#
## df_test = df_from_xml('Test')
## df = df_dev.append(df_test, ignore_index=True)
#df = df.loc[:, ['title', 'language', 'year', 'genre', 'country', 'runtime', 'rated']]
#df.runtime = df.runtime.apply(lambda x: x[:-4])
#df.rated.replace(['NOT RATED', 'UNRATED'], 'N/A', inplace=True)
#df.year = pd.to_numeric(df.year, errors='coerce')
#df.runtime = pd.to_numeric(df.runtime, errors='coerce')
#    
##df_dev = df.iloc[:95]
##df_test = df.iloc[95:]
#labels = pd.read_excel(r'Dev_Set\dev_set_groundtruth_and_trailers.xls', index_col=0).goodforairplane
## labels_test = pd.read_csv(r'Test_Set\CoeTestLabels.csv', index_col=0).goodforairplanes
#df.set_index('title', inplace=True)
## df_dev = df_dev.merge(labels_dev, left_index=True, right_index=True)
## df_test.set_index('title', inplace=True)
## df_test = df_test.merge(labels_test, left_index=True, right_index=True)
## df_test.shape
